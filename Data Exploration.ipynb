# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:/Users/Puja Shaw/OneDrive/Desktop/myntra_products_catalog.csv") #importing the dataset

# %%
df.head() #displaying the top 5 entries in our dataframe
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3  Blue self-design bandhgala suitBlue self-desig...         Blue
# 4  Brown and off-white printed casual shirt, has ...        White

# %%
pd.set_option('display.max_columns', None) #to show all the columns of the dataset

# %%
df.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3  Blue self-design bandhgala suitBlue self-desig...         Blue
# 4  Brown and off-white printed casual shirt, has ...        White

# %%
df.columns #To see what are the columns available in your data
# Out:
# Index(['ProductID', 'ProductName', 'ProductBrand', 'Gender', 'Price (INR)',
#        'NumImages', 'Description', 'PrimaryColor'],
#       dtype='object')

# %%
df.dtypes #lets get the data types of all the columns
# Out:
# ProductID        int64
# ProductName     object
# ProductBrand    object
# Gender          object
# Price (INR)      int64
# NumImages        int64
# Description     object
# PrimaryColor    object
# dtype: object

# %%
df.select_dtypes(include=np.number) #lets get the numerical columns only
# Out:
#        ProductID  Price (INR)  NumImages
# 0       10017413        11745          7
# 1       10016283         5810          7
# 2       10009781          899          7
# 3       10015921         5599          5
# 4       10017833          759          5
# ...          ...          ...        ...
# 12486   10262843         1299          7
# 12487   10261721         1990          5
# 12488   10261607          602          4
# 12489   10266621         8950          2
# 12490   10265199          799          5
#
# [12491 rows x 3 columns]

# %%
df.select_dtypes(include=np.number).columns #lets get the names of the numerical columns only
# Out:
# Index(['ProductID', 'Price (INR)', 'NumImages'], dtype='object')

# %%
df.select_dtypes(exclude=np.number).columns #lets get the names of the nonnumerical columns only
# Out:
# Index(['ProductName', 'ProductBrand', 'Gender', 'Description', 'PrimaryColor'], dtype='object')

# %%
df.select_dtypes(exclude=np.number) #lets get the categorical columns only
# Out:
#                                              ProductName ProductBrand  Gender  \
# 0      DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY  Unisex
# 1      EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue   Women
# 2      SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR   Women
# 3      Raymond Men Blue Self-Design Single-Breasted B...      Raymond     Men
# 4      Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx     Men
# ...                                                  ...          ...     ...
# 12486  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...   Pepe Jeans     Men
# 12487                 Mochi Women Gold-Toned Solid Heels        Mochi   Women
# 12488  612 league Girls Navy Blue & White Printed Reg...   612 league   Girls
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...      Bvlgari     Men
# 12490  Pepe Jeans Men Black & Grey Striped Polo Colla...   Pepe Jeans     Men
#
#                                              Description PrimaryColor
# 0      Black and grey printed medium trolley bag, sec...        Black
# 1      Beige & Grey made to measure kurta with churid...        Beige
# 2      Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3      Blue self-design bandhgala suitBlue self-desig...         Blue
# 4      Brown and off-white printed casual shirt, has ...        White
# ...                                                  ...          ...
# 12486  Black dark wash 5-pocket low-rise jeans, clean...        Black
# 12487  A pair of gold-toned open toe heels, has regul...         Gold
# 12488  Navy Blue and White printed mid-rise denim sho...         Blue
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...          NaN
# 12490  Black and grey striped T-shirt, has a polo col...        Black
#
# [12491 rows x 5 columns]

# %%
df.shape #lets get the shape of the dataset
# Out:
# (12491, 8)

# %%
df.info() #lets display the important informationabout the dataframe
          #column names,number of non-null rows in each column,data type of the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12491 entries, 0 to 12490
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     12491 non-null  int64
#  1   ProductName   12491 non-null  object
#  2   ProductBrand  12491 non-null  object
#  3   Gender        12491 non-null  object
#  4   Price (INR)   12491 non-null  int64
#  5   NumImages     12491 non-null  int64
#  6   Description   12491 non-null  object
#  7   PrimaryColor  11597 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 780.8+ KB

# %%
df.describe() #lets display the important statistics of the dataset(numerical columns)
# Out:
#           ProductID   Price (INR)     NumImages
# count  1.249100e+04  12491.000000  12491.000000
# mean   9.917160e+06   1452.660956      4.913698
# std    1.438006e+06   2118.503976      1.092333
# min    1.012060e+05     90.000000      1.000000
# 25%    1.006215e+07    649.000000      5.000000
# 50%    1.015463e+07    920.000000      5.000000
# 75%    1.021565e+07   1499.000000      5.000000
# max    1.027514e+07  63090.000000     10.000000

# %%
df.isnull().sum() #lets display if any null value present or not
# Out:
# ProductID         0
# ProductName       0
# ProductBrand      0
# Gender            0
# Price (INR)       0
# NumImages         0
# Description       0
# PrimaryColor    894
# dtype: int64

# %%
df.isna().sum() #lets display if any null value present or not
# Out:
# ProductID         0
# ProductName       0
# ProductBrand      0
# Gender            0
# Price (INR)       0
# NumImages         0
# Description       0
# PrimaryColor    894
# dtype: int64

# %%
df[df['PrimaryColor'].isna()] #checking the null value of a particular column
# Out:
#        ProductID                                        ProductName  \
# 12      10001989   Police Men To Be The King Eau De Toilette 125 ml
# 20      10001265  Michael Kors Women Sexy Amber Eau de Parfum 100ml
# 29      10012767  SEJ by Nisha Gupta Set of 6 Printed Table Plac...
# 39      10001111           ANNA SUI Women La Vie De Boheme EDT 75ml
# 80      10000805  Lady Lyka Women Pack of 2 Beginners Bras TEENA...
# ...          ...                                                ...
# 12475   10266619       GUESS Men 1981 Indigo Eau De Toilette 100 ml
# 12477    1027080                     Sonari Pack of 2 Bras cristina
# 12481    1026753                       Sonari Pack of 2 Bras afreen
# 12483    1027008         Sonari Pack of 2 Full-Coverage Bras celina
# 12489   10266621  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
#
#              ProductBrand  Gender  Price (INR)  NumImages  \
# 12                 Police     Men         2695          5
# 20           Michael Kors   Women         7920          3
# 29     SEJ by Nisha Gupta  Unisex          899          4
# 39               ANNA SUI   Women         4600          4
# 80              Lady Lyka   Women          425          5
# ...                   ...     ...          ...        ...
# 12475               GUESS     Men         2314          6
# 12477              Sonari   Women          940          4
# 12481              Sonari   Women          750          4
# 12483              Sonari   Women          920          2
# 12489             Bvlgari     Men         8950          2
#
#                                              Description PrimaryColor
# 12                       To Be The King Eau De Toilette           NaN
# 20     Michael Kors Sexy Amber Eau de ParfumFragrance...          NaN
# 29     Set content: 6 table mats Shape: Rectangle Col...          NaN
# 39     ANNA SUI La Vie De Boheme Eau De ToiletteStron...          NaN
# 80     Black and white solid medium-coverage beginner...          NaN
# ...                                                  ...          ...
# 12475       GUESS 1981 Indigo Pour Homme Eau De Toilette          NaN
# 12477  Pack of two full-coverage bras in cream-colour...          NaN
# 12481  Pack of two full-coverage bras in pink and mar...          NaN
# 12483  Pack of two full-coverage bras in whiteEach ha...          NaN
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...          NaN
#
# [894 rows x 8 columns]

# %%
df.hist(bins=60) #let's see the distribution of datapoints in each numerical column
# Out:
# array([[<AxesSubplot:title={'center':'ProductID'}>,
#         <AxesSubplot:title={'center':'Price (INR)'}>],
#        [<AxesSubplot:title={'center':'NumImages'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.hist(bins=60, figsize=(20,10)) #increased plot size to make the histogram clearly visible
# Out:
# array([[<AxesSubplot:title={'center':'ProductID'}>,
#         <AxesSubplot:title={'center':'Price (INR)'}>],
#        [<AxesSubplot:title={'center':'NumImages'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.head() #let's check the data once again
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3  Blue self-design bandhgala suitBlue self-desig...         Blue
# 4  Brown and off-white printed casual shirt, has ...        White

# %%
df["Gender"].nunique() #let's see the unique values for a particular column of the dataset
# Out:
# 6

# %%
df["Gender"].unique() #let's see what are the unique entries column of the dataframe
# Out:
# array(['Unisex', 'Women', 'Men', 'Boys', 'Girls', 'Unisex Kids'],
#       dtype=object)

# %%
df["Gender"].value_counts() #let's see how many entries are there for each unique entry column of the dataframe
# Out:
# Women          5126
# Men            4591
# Unisex         1188
# Boys           1100
# Girls           440
# Unisex Kids      46
# Name: Gender, dtype: int64

# %%
df.nunique() #lets check the unique value for all the columns
# Out:
# ProductID       12491
# ProductName     10761
# ProductBrand      677
# Gender              6
# Price (INR)      1543
# NumImages          10
# Description     10435
# PrimaryColor       27
# dtype: int64

# %%
df['Gender'].value_counts().plot(kind='bar', figsize=(12,8)) #lets see the value counts in terms of a bar chart
# Out:
# <AxesSubplot:>

# %%
df.nunique()  #lets see the counts of unique values in all the columns of the dataset
# Out:
# ProductID       12491
# ProductName     10761
# ProductBrand      677
# Gender              6
# Price (INR)      1543
# NumImages          10
# Description     10435
# PrimaryColor       27
# dtype: int64

# %%
df[df['Price (INR)'] >2000] #lets check all the rows where price is more than 2000
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1       10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 9       10017421                DKNY Unisex Black Large Trolley Bag
# 10      10000911        Kenneth Cole Women Navy Blue Solid Backpack
# ...          ...                                                ...
# 12475   10266619       GUESS Men 1981 Indigo Eau De Toilette 100 ml
# 12476   10268041  Calvin Klein Jeans Men Blue Regular Fit Solid ...
# 12479   10275107          Vero Moda Women Black & White Checked Top
# 12480   10274295            INVU Men Blue Aviator Sunglasses B2945B
# 12489   10266621  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
#
#              ProductBrand  Gender  Price (INR)  NumImages  \
# 0                    DKNY  Unisex        11745          7
# 1              EthnoVogue   Women         5810          7
# 3                 Raymond     Men         5599          5
# 9                    DKNY  Unisex        17360          5
# 10           Kenneth Cole   Women         2463          5
# ...                   ...     ...          ...        ...
# 12475               GUESS     Men         2314          6
# 12476  Calvin Klein Jeans     Men         3599          5
# 12479           Vero Moda   Women         2299          6
# 12480                INVU     Men         2016          5
# 12489             Bvlgari     Men         8950          2
#
#                                              Description PrimaryColor
# 0      Black and grey printed medium trolley bag, sec...        Black
# 1      Beige & Grey made to measure kurta with churid...        Beige
# 3      Blue self-design bandhgala suitBlue self-desig...         Blue
# 9      Black solid large trolley bag, secured with a ...        Black
# 10     Navy Blue backpackNon-Padded haul loop1 main c...         Blue
# ...                                                  ...          ...
# 12475       GUESS 1981 Indigo Pour Homme Eau De Toilette          NaN
# 12476  Blue solid casual shirt, has a spread collar, ...         Blue
# 12479  Black and White checked knitted regular top, h...        Black
# 12480  Lens colour: BlueLens feature: UV Protected Le...         Blue
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...          NaN
#
# [1817 rows x 8 columns]

# %%
df[df['NumImages'] == 5] #lets check all the rows where numimage is 5
# Out:
#        ProductID                                        ProductName  \
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4       10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# 5       10014361    SHOWOFF Men Brown Solid Slim Fit Regular Shorts
# 6       10017869        Parx Men Blue Slim Fit Checked Casual Shirt
# 8       10000571  Parx Men Brown Tapered Fit Solid Regular Trousers
# ...          ...                                                ...
# 12480   10274295            INVU Men Blue Aviator Sunglasses B2945B
# 12482   10261845  Belle Fille Women Olive Green & White Polka Do...
# 12485   10261595  Laceandme Black Lace Non-Wired Lightly Padded ...
# 12487   10261721                 Mochi Women Gold-Toned Solid Heels
# 12490   10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand Gender  Price (INR)  NumImages  \
# 3          Raymond    Men         5599          5
# 4             Parx    Men          759          5
# 5          SHOWOFF    Men          791          5
# 6             Parx    Men          719          5
# 8             Parx    Men          664          5
# ...            ...    ...          ...        ...
# 12480         INVU    Men         2016          5
# 12482  Belle Fille  Women          799          5
# 12485    Laceandme  Women          569          5
# 12487        Mochi  Women         1990          5
# 12490   Pepe Jeans    Men          799          5
#
#                                              Description PrimaryColor
# 3      Blue self-design bandhgala suitBlue self-desig...         Blue
# 4      Brown and off-white printed casual shirt, has ...        White
# 5      Brown solid low-rise regular shorts, has four ...        Brown
# 6      Blue checked casual shirt, has a spread collar...         Blue
# 8          Brown solid regular trousers regular trousers          Red
# ...                                                  ...          ...
# 12480  Lens colour: BlueLens feature: UV Protected Le...         Blue
# 12482  Olive green and white polka dot print basic ju...        Green
# 12485  Black lace full-coverage Bralette bra Lightly ...          Red
# 12487  A pair of gold-toned open toe heels, has regul...         Gold
# 12490  Black and grey striped T-shirt, has a polo col...        Black
#
# [7134 rows x 8 columns]

# %% [markdown]
# **Thank You**
